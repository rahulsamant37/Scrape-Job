# %%
import pandas as pd
df=pd.read_csv('careerjet_all_jobs_20250110_162215.csv')

# %%
df.head()
# Out:
#             job_type country  \
# 0  software engineer   Japan
# 1  software engineer   Japan
# 2  software engineer   Japan
# 3  software engineer   Japan
# 4  software engineer   Japan
#
#                                                title                company  \
# 0  エンジニア／Data Engineer【正社員】【インターネット関連】【リモートワーク可】【...                    NaN
# 1  AVP, EMEA, APAC and Japan Strategic Customer E...             ServiceNow
# 2                           R&D Engineer 4, Software  Keysight Technologies
# 3  AVP, EMEA, APAC and Japan Strategic Customer E...             ServiceNow
# 4  AVP, EMEA, APAC and Japan Strategic Customer E...             ServiceNow
#
#          locations                       salary  \
# 0            Tokyo  5000000 - 10000000 per year
# 1            Japan                          NaN
# 2  Hachiōji, Tokyo                          NaN
# 3            Japan                          NaN
# 4            Japan                          NaN
#
# ...
